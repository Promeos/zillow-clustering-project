# %% [markdown]
# <img src="https://prnewswire2-a.akamaihd.net/p/1893751/sp/189375100/thumbnail/entry_id/1_su9da4fu/def_height/1001/def_width/1911/version/100011/type/2/q/100"  width="300" height="200">
#
# # Modeling

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from prepare import prepare_zillow
from wrangle import train_validate_test, impute_values
from explore import cluster_features

from warnings import filterwarnings
filterwarnings('ignore')

# %%
df = prepare_zillow()

# %%
columns_to_drop = ['parcelid', 'date_sold']

# %%
df.drop(columns=columns_to_drop, inplace=True)

# %%
train, validate, test = train_validate_test(df)
train, validate, test = impute_values(train, validate, test)

# %%
train.describe()
# Out:
#        num_of_bedrooms  num_of_restrooms  living_room_area_sqft  \
# count     31463.000000      31463.000000           31463.000000
# mean          3.312367          2.306980            1928.402028
# std           0.935700          1.026015            1010.014845
# min           1.000000          1.000000             128.000000
# 25%           3.000000          2.000000            1270.000000
# 50%           3.000000          2.000000            1661.000000
# 75%           4.000000          3.000000            2308.500000
# max          14.000000         18.000000           18654.000000
#
#        lot_size_sqft    year_built  has_basement  has_hottub_or_spa  \
# count   3.146300e+04  31463.000000  31463.000000       31463.000000
# mean    1.116874e+04   1963.462035      0.000922           0.030321
# std     7.645269e+04     23.106205      0.030346           0.171473
# min     5.400000e+02   1885.000000      0.000000           0.000000
# ...

# %%
train, validate, test = cluster_features(train, validate, test)

# %%
train.head()

# %%
train_cluster_1_dummies = pd.get_dummies(train.cluster_1, drop_first=True, prefix='cluster_1')
validate_cluster_1_dummies = pd.get_dummies(validate.cluster_1, drop_first=True, prefix='cluster_1')
test_cluster_1_dummies = pd.get_dummies(test.cluster_1, drop_first=True, prefix='cluster_1')

# %%
train_cluster_2_dummies = pd.get_dummies(train.cluster_2, drop_first=True, prefix='cluster_2')
validate_cluster_2_dummies = pd.get_dummies(validate.cluster_2, drop_first=True, prefix='cluster_2')
test_cluster_2_dummies = pd.get_dummies(test.cluster_2, drop_first=True, prefix='cluster_2')

# %%
train_cluster_3_dummies = pd.get_dummies(train.cluster_3, drop_first=True, prefix='cluster_3')
validate_cluster_3_dummies = pd.get_dummies(validate.cluster_3, drop_first=True, prefix='cluster_3')
test_cluster_3_dummies = pd.get_dummies(test.cluster_3, drop_first=True, prefix='cluster_3')

# %%
train = pd.concat([
    train,
    train_cluster_1_dummies,
    train_cluster_2_dummies,
    train_cluster_3_dummies],
    axis=1
)

# %%
validate = pd.concat([
    validate,
    validate_cluster_1_dummies,
    validate_cluster_2_dummies,
    validate_cluster_3_dummies],
    axis=1
)

# %%
test = pd.concat([
    test,
    test_cluster_1_dummies,
    test_cluster_2_dummies,
    test_cluster_3_dummies],
    axis=1
)

# %%
train.head()
